# %% [markdown]
# # Model comparison
#
# Cross-validated (GroupKFold by driver) comparison of each model vs its
# baseline, using the shared `ml.evaluation` harness (#54). Requires
# `pip install -e ".[analytics]"`.

# %%
from fastf1_analytics import session_laps
from ml import compare_classification, compare_regression

laps = session_laps(2023, "Singapore", "R")

# %%
compare_regression(laps)  # lap-time regression vs mean baseline

# %%
compare_classification(laps)  # compound classification vs majority baseline
