# %% [markdown]
# # Lap telemetry
#
# A thin notebook over the `fastf1_analytics` helpers (#40) — all load / prepare
# / plot logic lives in the tested module, so this stays a few lines. Requires
# the analytics extra: `pip install -e ".[analytics]"`.

# %%
from fastf1_analytics import plot_fastest_laps, plot_lap_pace, session_laps, stint_summary

laps = session_laps(2023, "Singapore", "R")  # cleaned laps DataFrame (cached after first load)
laps.head()

# %%
plot_lap_pace(laps, drivers=["VER", "HAM", "SAI"]);

# %%
plot_fastest_laps(laps);

# %%
stint_summary(laps)
